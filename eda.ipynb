# %%
import geopandas as gpd


# Percorso ai dati dei comuni
comuni_shapefile = 'data/Limiti01012024_g/Com01012024_g/Com01012024_g_WGS84.shp'

comuni = gpd.read_file(comuni_shapefile)

comuni
# Out:
#       COD_RIP  COD_REG  COD_PROV  COD_CM  COD_UTS  PRO_COM PRO_COM_T  \
# 0           1        1         1       0      201     1001    001001
# 1           1        1         1       0      201     1002    001002
# 2           1        1         1       0      201     1003    001003
# 3           1        1         1       0      201     1004    001004
# 4           1        1         1       0      201     1006    001006
# ...       ...      ...       ...     ...      ...      ...       ...
# 7894        5       20       111       0      111   111093    111093
# 7895        5       20       111       0      111   111094    111094
# 7896        5       20       111       0      111   111095    111095
# 7897        5       20       111       0      111   111096    111096
# 7898        5       20       111       0      111   111097    111097
#
#                COMUNE COMUNE_A  CC_UTS    Shape_Leng    Shape_Area  \
# 0               Agliè        0       0  16075.204018  1.328507e+07
# ...

# %%
comuni[comuni['PRO_COM_T'] == '001777']
# Out:
# Empty GeoDataFrame
# Columns: [COD_RIP, COD_REG, COD_PROV, COD_CM, COD_UTS, PRO_COM, PRO_COM_T, COMUNE, COMUNE_A, CC_UTS, Shape_Leng, Shape_Area, geometry]
# Index: []
